# %%
from hacr_e import kfold_enter_test

# %%
kfold_enter_test(False, False)
# Out:
# gt_human_face: False
# gt_abt:        False
#
# -------Run 0-------
# Running ILASP on 8 training examples...
# Learnt rule: initiates(enter(V1),at_curr_location(V1),V2) :- holdsAt(in_camera(V1),V2); not holdsAt(at_curr_location(V1),V2).
# qid: 25625601   ans_idx: 3    gt_ans: Sheldon
# poss_people: {'stuart', 'sheldon'}   pred_ans_idx: [3]
# qid: 25625602   ans_idx: 3    gt_ans: Penny and Bernadette
# poss_people: {'penny', 'barry'}   pred_ans_idx: [3]
# # tests:     2
# jacc score:   2.0
# norm jacc score: 1.0
#
# NOT FULL SCORE
# []
#
# ZERO SCORE
# []
# ----------------------------
#
# -------Run 1-------
# Running ILASP on 8 training examples...
# Learnt rule: initiates(enter(V1),at_curr_location(V1),V2) :- holdsAt(in_camera(V1),V2); not holdsAt(at_curr_location(V1),V2).
# qid: 25625603   ans_idx: 2    gt_ans: Sheldon
# poss_people: {'penny', 'sheldon'}   pred_ans_idx: [1, 2]
# qid: 25625604   ans_idx: 0    gt_ans: Sheldon
# ...

# %%
kfold_enter_test(False, True)
# Out:
# gt_human_face: False
# gt_abt:        True
#
# -------Run 0-------
# Running ILASP on 8 training examples...
# Learnt rule: initiates(enter(V1),at_curr_location(V1),V2) :- holdsAt(in_camera(V1),V2); not holdsAt(at_curr_location(V1),V2).
# qid: 25625601   ans_idx: 3    gt_ans: Sheldon
# poss_people: {'raj', 'leonard', 'stuart', 'sheldon'}   pred_ans_idx: [3, 4]
# qid: 25625602   ans_idx: 3    gt_ans: Penny and Bernadette
# poss_people: {'penny', 'barry', 'amy'}   pred_ans_idx: [3]
# # tests:     2
# jacc score:   1.5
# norm jacc score: 0.75
#
# NOT FULL SCORE
# [25625601]
#
# ZERO SCORE
# []
# ----------------------------
#
# -------Run 1-------
# Running ILASP on 8 training examples...
# Learnt rule: initiates(enter(V1),at_curr_location(V1),V2) :- holdsAt(in_camera(V1),V2); not holdsAt(at_curr_location(V1),V2).
# qid: 25625603   ans_idx: 2    gt_ans: Sheldon
# poss_people: {'sheldon', 'raj', 'howard', 'leonard', 'penny'}   pred_ans_idx: [1, 2]
# ...

# %%
kfold_enter_test(True, False)
# Out:
# gt_human_face: True
# gt_abt:        False
#
# -------Run 0-------
# Running ILASP on 8 training examples...
# Learnt rule: initiates(enter(V1),at_curr_location(V1),V2) :- holdsAt(in_camera(V1),V2); not holdsAt(at_curr_location(V1),V2).
# qid: 25625601   ans_idx: 3    gt_ans: Sheldon
# poss_people: {'howard', 'sheldon'}   pred_ans_idx: [3]
# qid: 25625602   ans_idx: 3    gt_ans: Penny and Bernadette
# poss_people: {'penny', 'bernadette'}   pred_ans_idx: [3]
# # tests:     2
# jacc score:   2.0
# norm jacc score: 1.0
#
# NOT FULL SCORE
# []
#
# ZERO SCORE
# []
# ----------------------------
#
# -------Run 1-------
# Running ILASP on 8 training examples...
# Learnt rule: initiates(enter(V1),at_curr_location(V1),V2) :- holdsAt(in_camera(V1),V2); not holdsAt(at_curr_location(V1),V2).
# qid: 25625603   ans_idx: 2    gt_ans: Sheldon
# poss_people: {'sheldon'}   pred_ans_idx: [2]
# qid: 25625604   ans_idx: 0    gt_ans: Sheldon
# poss_people: {'howard', 'sheldon'}   pred_ans_idx: [0]
# ...

# %%
kfold_enter_test(True, True)
# Out:
# gt_human_face: True
# gt_abt:        True
#
# -------Run 0-------
# Running ILASP on 8 training examples...
# Learnt rule: initiates(enter(V1),at_curr_location(V1),V2) :- holdsAt(in_camera(V1),V2); not holdsAt(at_curr_location(V1),V2).
# qid: 25625601   ans_idx: 3    gt_ans: Sheldon
# poss_people: {'howard', 'raj', 'leonard', 'sheldon'}   pred_ans_idx: [3, 4]
# qid: 25625602   ans_idx: 3    gt_ans: Penny and Bernadette
# poss_people: {'penny', 'bernadette', 'amy'}   pred_ans_idx: [0, 1, 3]
# # tests:     2
# jacc score:   0.8333333333333333
# norm jacc score: 0.41666666666666663
#
# NOT FULL SCORE
# [25625601, 25625602]
#
# ZERO SCORE
# []
# ----------------------------
#
# -------Run 1-------
# Running ILASP on 8 training examples...
# Learnt rule: initiates(enter(V1),at_curr_location(V1),V2) :- holdsAt(in_camera(V1),V2); not holdsAt(at_curr_location(V1),V2).
# qid: 25625603   ans_idx: 2    gt_ans: Sheldon
# poss_people: {'howard', 'raj', 'leonard', 'sheldon'}   pred_ans_idx: [2]
# ...
